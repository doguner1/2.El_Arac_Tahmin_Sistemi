# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

data = pd.read_csv(r"C:\Users\huawe\Documents\Yazilim\2.El_Arac_Tahmin_Sistemi\turkey_car_market.csv")
data.head()
# Out:
#   İlan Tarihi   Marka Arac Tip Grubu             Arac Tip  Model Yıl  \
# 0  27/05/2020  Jaguar             XF  2.0 D Prestige Plus     2017.0
# 1  16/06/2020   Acura             CL                    -     2015.0
# 2  14/06/2020   Acura             CL                  2.2     1994.0
# 3  11/06/2020   Acura             CL                    -     2013.0
# 4  11/06/2020   Acura             CL                  2.2     2010.0
#
#    Yakıt Turu                Vites           CCM Beygir Gucu         Renk  \
# 0       Dizel       Otomatik Vites  1801-2000 cc  176-200 BG    Lacivert
# 1       Dizel  Yarı Otomatik Vites  1301-1600 cc  101-125 BG        Mavi
# 2  Benzin/LPG            Düz Vites  1301-1600 cc  101-125 BG     Turkuaz
# 3       Dizel            Düz Vites  1301-1600 cc   76-100 BG  Kahverengi
# 4       Dizel       Otomatik Vites  1801-2000 cc  151-175 BG       Beyaz
#
#           Kasa Tipi      Kimden  Durum      Km   Fiyat
# 0  Hatchback 5 Kapı   Galeriden  2. El   26100  634500
# 1             Sedan  Sahibinden  2. El  127000  151500
# 2             Sedan  Sahibinden  2. El  175000   19750
# 3             Sedan  Sahibinden  2. El     325   52000
# 4             Sedan  Sahibinden  2. El  207000  148750

# %%
değişkenler = data.columns
değişkenler
# Out:
# Index(['İlan Tarihi', 'Marka', 'Arac Tip Grubu', 'Arac Tip', 'Model Yıl',
#        'Yakıt Turu', 'Vites', 'CCM', 'Beygir Gucu', 'Renk', 'Kasa Tipi',
#        'Kimden', 'Durum', 'Km', 'Fiyat'],
#       dtype='object')

# %%
data.isnull().sum()/len(data)
"Eksik değer kontrolü"
# Out:
# 'Eksik değer kontrolü'

# %%
for i in değişkenler:

    print(i, len(data.loc[data[i] == "BosDeger"]))
# Out:
# İlan Tarihi 0
# Marka 0
# Arac Tip Grubu 0
# Arac Tip 0
# Model Yıl 0
# Yakıt Turu 0
# Vites 0
# CCM 108
# Beygir Gucu 5549
# Renk 0
# Kasa Tipi 0
# Kimden 0
# Durum 0
# Km 0
# Fiyat 0

# %%
q1 = data["Fiyat"].quantile(0.25)
q3 = data["Fiyat"].quantile(0.75)

IOC = q3 - q1
"IQR (Interquartile Range - Çeyrekler Arası Aralık)"

alt_sınır = q1 - 1.5*IOC
üst_sınır = q3 + 1.5*IOC

kontrol = (data["Fiyat"] < alt_sınır) | (data["Fiyat"] > üst_sınır)
data["Asırı_Deger"] = kontrol
data["Asırı_Deger"].value_counts()
# Out:
# Asırı_Deger
# False    8285
# True      759
# Name: count, dtype: int64

# %%
"759 Tane Aşırı değer çıktı. Bu değerleri veri tablomuzdan çıkarıyoruz."
data = data.loc[data["Asırı_Deger"] == False]

data.head()
# Out:
#   İlan Tarihi  Marka Arac Tip Grubu Arac Tip  Model Yıl  Yakıt Turu  \
# 1  16/06/2020  Acura             CL        -     2015.0       Dizel
# 2  14/06/2020  Acura             CL      2.2     1994.0  Benzin/LPG
# 3  11/06/2020  Acura             CL        -     2013.0       Dizel
# 4  11/06/2020  Acura             CL      2.2     2010.0       Dizel
# 5  04/06/2020  Acura             CL      2.2     1999.0       Dizel
#
#                  Vites           CCM Beygir Gucu         Renk Kasa Tipi  \
# 1  Yarı Otomatik Vites  1301-1600 cc  101-125 BG        Mavi      Sedan
# 2            Düz Vites  1301-1600 cc  101-125 BG     Turkuaz      Sedan
# 3            Düz Vites  1301-1600 cc   76-100 BG  Kahverengi      Sedan
# 4       Otomatik Vites  1801-2000 cc  151-175 BG       Beyaz      Sedan
# 5            Düz Vites  1801-2000 cc  101-125 BG    Lacivert   Roadster
#
#        Kimden  Durum      Km   Fiyat  Asırı_Deger
# 1  Sahibinden  2. El  127000  151500        False
# 2  Sahibinden  2. El  175000   19750        False
# 3  Sahibinden  2. El     325   52000        False
# 4  Sahibinden  2. El  207000  148750        False
# 5   Galeriden  2. El  320000   42500        False

# %%
round(pd.pivot_table(data = data, columns = "Marka", values = "Fiyat")).T
"Markaların Ortalama Fiyat Listesi"
# Out:
# 'Markaların Ortalama Fiyat Listesi'

# %%
fig, ax = plt.subplots(figsize=(20, 6))
sns.barplot(x = data.loc[data["Marka"] == "Opel"]["Model Yıl"], y = data["Fiyat"])
# Out:
# <Axes: xlabel='Model Yıl', ylabel='Fiyat'>

# %%
fig, ax = plt.subplots(figsize=(20, 6))
sns.barplot(x = data.loc[data["Marka"] == "Renault"]["Model Yıl"], y = data["Fiyat"])
# Out:
# <Axes: xlabel='Model Yıl', ylabel='Fiyat'>

# %%
fig, ax = plt.subplots(figsize=(20, 6))
sns.barplot(x = data.loc[data["Marka"] == "Hyundai"]["Model Yıl"], y = data["Fiyat"])
# Out:
# <Axes: xlabel='Model Yıl', ylabel='Fiyat'>

# %%
fig, ax = plt.subplots(figsize=(20, 6))
sns.barplot(x = data.loc[data["Marka"] == "Honda"]["Model Yıl"], y = data["Fiyat"])
# Out:
# <Axes: xlabel='Model Yıl', ylabel='Fiyat'>

# %%
honda = data.loc[data["Marka"] == "Honda"]
honda_2006 = honda.loc[honda["Model Yıl"] == 2006]
honda_2006
# Out:
#      İlan Tarihi  Marka Arac Tip Grubu             Arac Tip  Model Yıl  \
# 3014  12/06/2020  Honda           CR-V  1.6 i-DTEC Elegance     2006.0
# 3123  18/04/2020  Honda          Civic      1.6i VTEC Dream     2006.0
# 3196  17/04/2020  Honda           City            1.4 Elite     2006.0
#
#       Yakıt Turu                Vites           CCM Beygir Gucu        Renk  \
# 3014       Dizel       Otomatik Vites  1601-1800 cc  151-175 BG      Beyaz
# 3123  Benzin/LPG       Otomatik Vites  1301-1600 cc    BosDeger  Gümüş Gri
# 3196      Benzin  Yarı Otomatik Vites  1301-1600 cc    BosDeger   Şampanya
#
#         Kasa Tipi     Kimden  Durum      Km   Fiyat  Asırı_Deger
# 3014  Arazi Aracı  Galeriden  2. El   98000  249700        False
# 3123        Sedan  Galeriden  2. El  206000   72500        False
# 3196        Sedan  Galeriden  2. El   93000   66000        False

# %%
arazi = data.loc[data["Kasa Tipi"] == "Arazi Aracı"]
arazi_2006 = arazi.loc[arazi["Model Yıl"] == 2006]
arazi_2006
# Out:
#      İlan Tarihi       Marka     Arac Tip Grubu               Arac Tip  \
# 63    09/04/2020        Audi                 Q7        3.0 TDI Quattro
# 70    15/06/2020        Audi                 Q7        3.0 TDI Quattro
# 142   09/04/2020        Audi                 Q7        3.0 TDI Quattro
# 354   17/04/2020        Audi                 Q7        3.0 TDI Quattro
# 451   09/04/2020        Audi                 Q7        3.0 TDI Quattro
# 637   19/04/2020         BMW                 X5  3.0d xDrive Exclusive
# 789   18/04/2020         BMW                 X5                    30d
# 961   09/04/2020        Audi                 Q7        3.0 TDI Quattro
# 1001  09/04/2020        Audi                 Q7        3.0 TDI Quattro
# 1354  09/04/2020        Audi                 Q7        3.0 TDI Quattro
# 2486  27/05/2020        Ford             Ranger           2.5 TDCi STD
# 2728  09/04/2020        Audi                 Q7        3.0 TDI Quattro
# 2862  09/04/2020        Audi                 Q7        3.0 TDI Quattro
# 3014  12/06/2020       Honda               CR-V    1.6 i-DTEC Elegance
# 3029  09/04/2020        Audi                 Q7        3.0 TDI Quattro
# 3479  11/05/2020     Hyundai             Tucson         2.0 CRDi Style
# 3682  09/04/2020        Audi                 Q7        3.0 TDI Quattro
# 3873  17/04/2020    Infiniti                 FX                   FX35
# 3879  18/04/2020       Isuzu              D-Max              3.0 D 4x4
# 3886  09/04/2020        Audi                 Q7        3.0 TDI Quattro
# 3942  14/06/2020         Kia            Sorento    2.5 CRDi EX Premium
# 3960  29/05/2020         Kia            Sorento    2.5 CRDi EX Premium
# 3997  18/04/2020         Kia            Sorento            2.5 CRDi EX
# 4003  18/04/2020         Kia           Sportage            2.0 CRDi EX
# 4060  18/04/2020         Kia            Sorento    2.5 CRDi EX Premium
# 4061  18/04/2020         Kia            Sorento    2.5 CRDi EX Premium
# 4105  01/04/2020         Kia            Sorento            2.5 CRDi EX
# 4155  12/05/2020  Land Rover         Freelander            2.0 TD4 HSE
# 4172  28/04/2020  Land Rover         Freelander            2.0 TD4 HSE
# 4201  18/04/2020  Land Rover  Range Rover Sport           2.7 TDV6 HSE
# 4202  18/04/2020  Land Rover        Range Rover          3.0 TD6 Vogue
# 4220  18/04/2020  Land Rover         Freelander            2.0 TD4 HSE
# 4251  17/04/2020  Land Rover  Range Rover Sport           2.7 TDV6 HSE
# 4257  17/04/2020  Land Rover        Range Rover            3.0 TD6 HSE
# 4280  17/04/2020  Land Rover         Freelander            2.0 TD4 HSE
# 4283  17/04/2020  Land Rover          Discovery               2.7 TDV6
# 4295  28/03/2020  Land Rover         Freelander            2.0 TD4 HSE
# 4481  09/04/2020        Audi                 Q7        3.0 TDI Quattro
# 4908  09/04/2020        Audi                 Q7        3.0 TDI Quattro
# 5153  18/04/2020      Nissan            Skystar            Skystar 4x2
# 5291  09/04/2020        Audi                 Q7        3.0 TDI Quattro
# 5391  09/04/2020        Audi                 Q7        3.0 TDI Quattro
# 5721  09/04/2020        Audi                 Q7        3.0 TDI Quattro
# 6163  09/04/2020        Audi                 Q7        3.0 TDI Quattro
# 6356  24/04/2020     Porsche            Cayenne                 3.2 V6
# 6938  09/04/2020        Audi                 Q7        3.0 TDI Quattro
# 7125  09/04/2020        Audi                 Q7        3.0 TDI Quattro
# 7223  09/04/2020        Audi                 Q7        3.0 TDI Quattro
# 7362  09/04/2020        Audi                 Q7        3.0 TDI Quattro
#
#       Model Yıl  Yakıt Turu                Vites           CCM Beygir Gucu  \
# 63       2006.0       Dizel       Otomatik Vites  2501-3000 cc  276-300 BG
# 70       2006.0       Dizel       Otomatik Vites  2501-3000 cc  226-250 BG
# 142      2006.0       Dizel       Otomatik Vites  2501-3000 cc  276-300 BG
# 354      2006.0       Dizel       Otomatik Vites  2501-3000 cc    BosDeger
# 451      2006.0       Dizel       Otomatik Vites  2501-3000 cc  276-300 BG
# 637      2006.0       Dizel       Otomatik Vites  2501-3000 cc  251-275 BG
# 789      2006.0       Dizel       Otomatik Vites  2501-3000 cc    BosDeger
# 961      2006.0       Dizel       Otomatik Vites  2501-3000 cc  276-300 BG
# 1001     2006.0       Dizel       Otomatik Vites  2501-3000 cc  276-300 BG
# 1354     2006.0       Dizel       Otomatik Vites  2501-3000 cc  276-300 BG
# 2486     2006.0       Dizel            Düz Vites  2001-2500 cc    BosDeger
# 2728     2006.0       Dizel       Otomatik Vites  2501-3000 cc  276-300 BG
# 2862     2006.0       Dizel       Otomatik Vites  2501-3000 cc  276-300 BG
# 3014     2006.0       Dizel       Otomatik Vites  1601-1800 cc  151-175 BG
# 3029     2006.0       Dizel       Otomatik Vites  2501-3000 cc  276-300 BG
# 3479     2006.0       Dizel            Düz Vites  1801-2000 cc  101-125 BG
# 3682     2006.0       Dizel       Otomatik Vites  2501-3000 cc  276-300 BG
# 3873     2006.0  Benzin/LPG       Otomatik Vites  3001-3500 cc    BosDeger
# 3879     2006.0       Dizel       Otomatik Vites  2501-3000 cc    BosDeger
# 3886     2006.0       Dizel       Otomatik Vites  2501-3000 cc  276-300 BG
# 3942     2006.0       Dizel       Otomatik Vites  2001-2500 cc  126-150 BG
# 3960     2006.0       Dizel       Otomatik Vites  2001-2500 cc  151-175 BG
# 3997     2006.0       Dizel       Otomatik Vites  2001-2500 cc    BosDeger
# 4003     2006.0       Dizel       Otomatik Vites  1801-2000 cc    BosDeger
# 4060     2006.0       Dizel       Otomatik Vites  2001-2500 cc    BosDeger
# 4061     2006.0       Dizel       Otomatik Vites  2001-2500 cc    BosDeger
# 4105     2006.0       Dizel       Otomatik Vites  2001-2500 cc  101-125 BG
# 4155     2006.0       Dizel  Yarı Otomatik Vites  1801-2000 cc    BosDeger
# 4172     2006.0       Dizel  Yarı Otomatik Vites  1801-2000 cc    BosDeger
# 4201     2006.0       Dizel       Otomatik Vites  2501-3000 cc    BosDeger
# 4202     2006.0       Dizel  Yarı Otomatik Vites  2501-3000 cc    BosDeger
# 4220     2006.0       Dizel  Yarı Otomatik Vites  1801-2000 cc    BosDeger
# 4251     2006.0       Dizel       Otomatik Vites  2501-3000 cc    BosDeger
# 4257     2006.0       Dizel  Yarı Otomatik Vites  2501-3000 cc    BosDeger
# 4280     2006.0       Dizel  Yarı Otomatik Vites  1801-2000 cc    BosDeger
# 4283     2006.0       Dizel       Otomatik Vites  2501-3000 cc    BosDeger
# 4295     2006.0       Dizel  Yarı Otomatik Vites  1801-2000 cc  101-125 BG
# 4481     2006.0       Dizel       Otomatik Vites  2501-3000 cc  276-300 BG
# 4908     2006.0       Dizel       Otomatik Vites  2501-3000 cc  276-300 BG
# 5153     2006.0       Dizel            Düz Vites  2001-2500 cc    BosDeger
# 5291     2006.0       Dizel       Otomatik Vites  2501-3000 cc  276-300 BG
# 5391     2006.0       Dizel       Otomatik Vites  2501-3000 cc  276-300 BG
# 5721     2006.0       Dizel       Otomatik Vites  2501-3000 cc  276-300 BG
# 6163     2006.0       Dizel       Otomatik Vites  2501-3000 cc  276-300 BG
# 6356     2006.0  Benzin/LPG       Otomatik Vites      BosDeger    BosDeger
# 6938     2006.0       Dizel       Otomatik Vites  2501-3000 cc  276-300 BG
# 7125     2006.0       Dizel       Otomatik Vites  2501-3000 cc  276-300 BG
# 7223     2006.0       Dizel       Otomatik Vites  2501-3000 cc  276-300 BG
# 7362     2006.0       Dizel       Otomatik Vites  2501-3000 cc  276-300 BG
#
#             Renk    Kasa Tipi      Kimden  Durum      Km   Fiyat  Asırı_Deger
# 63          Gri   Arazi Aracı   Galeriden  2. El  274654  162750        False
# 70        Siyah   Arazi Aracı   Galeriden  2. El  230000  155000        False
# 142         Gri   Arazi Aracı   Galeriden  2. El  274654  162750        False
# 354       Siyah   Arazi Aracı   Galeriden  2. El  230000  148000        False
# 451         Gri   Arazi Aracı   Galeriden  2. El  274654  162750        False
# 637       Siyah   Arazi Aracı  Sahibinden  2. El  370000  125000        False
# 789       Siyah   Arazi Aracı   Galeriden  2. El  264000  122000        False
# 961         Gri   Arazi Aracı   Galeriden  2. El  274654  162750        False
# 1001        Gri   Arazi Aracı   Galeriden  2. El  274654  162750        False
# 1354        Gri   Arazi Aracı   Galeriden  2. El  274654  162750        False
# 2486      Beyaz   Arazi Aracı   Galeriden  2. El  360000   44000        False
# 2728        Gri   Arazi Aracı   Galeriden  2. El  274654  162750        False
# 2862        Gri   Arazi Aracı   Galeriden  2. El  274654  162750        False
# 3014      Beyaz   Arazi Aracı   Galeriden  2. El   98000  249700        False
# 3029        Gri   Arazi Aracı   Galeriden  2. El  274654  162750        False
# 3479  Gümüş Gri   Arazi Aracı  Sahibinden  2. El  129000   85000        False
# 3682        Gri   Arazi Aracı   Galeriden  2. El  274654  162750        False
# 3873      Beyaz   Arazi Aracı   Galeriden  2. El  148000  122500        False
# 3879  Gümüş Gri   Arazi Aracı   Galeriden  2. El  211000   65000        False
# 3886        Gri   Arazi Aracı   Galeriden  2. El  274654  162750        False
# 3942      Siyah   Arazi Aracı  Sahibinden  2. El  186000   90000        False
# 3960  Gümüş Gri   Arazi Aracı   Galeriden  2. El  202000   67950        False
# 3997      Siyah   Arazi Aracı   Galeriden  2. El  253000   57000        False
# 4003      Siyah   Arazi Aracı   Galeriden  2. El  322400   64950        False
# 4060      Siyah   Arazi Aracı   Galeriden  2. El  201000   86950        False
# 4061      Siyah   Arazi Aracı   Galeriden  2. El  195000   63500        False
# 4105      Siyah   Arazi Aracı  Sahibinden  2. El  243000   85000        False
# 4155      Siyah   Arazi Aracı   Galeriden  2. El   91000  109500        False
# 4172      Siyah   Arazi Aracı   Galeriden  2. El  176000  115000        False
# 4201      Siyah   Arazi Aracı   Galeriden  2. El  149000  147750        False
# 4202      Siyah   Arazi Aracı   Galeriden  2. El  235000  159000        False
# 4220      Siyah   Arazi Aracı   Galeriden  2. El     350   79900        False
# 4251      Siyah   Arazi Aracı   Galeriden  2. El  289400  169000        False
# 4257        Gri   Arazi Aracı   Galeriden  2. El  266000  167500        False
# 4280      Siyah   Arazi Aracı   Galeriden  2. El   91000  109500        False
# 4283      Siyah   Arazi Aracı   Galeriden  2. El  289013  179500        False
# 4295      Siyah   Arazi Aracı  Sahibinden  2. El  385000   64250        False
# 4481        Gri   Arazi Aracı   Galeriden  2. El  274654  162750        False
# 4908        Gri   Arazi Aracı   Galeriden  2. El  274654  162750        False
# 5153      Siyah   Arazi Aracı   Galeriden  2. El  400000   45000        False
# 5291        Gri   Arazi Aracı   Galeriden  2. El  274654  162750        False
# 5391        Gri   Arazi Aracı   Galeriden  2. El  274654  162750        False
# 5721        Gri   Arazi Aracı   Galeriden  2. El  274654  162750        False
# 6163        Gri   Arazi Aracı   Galeriden  2. El  274654  162750        False
# 6356      Beyaz   Arazi Aracı   Galeriden  2. El  119000  180000        False
# 6938        Gri   Arazi Aracı   Galeriden  2. El  274654  162750        False
# 7125        Gri   Arazi Aracı   Galeriden  2. El  274654  162750        False
# 7223        Gri   Arazi Aracı   Galeriden  2. El  274654  162750        False
# 7362        Gri   Arazi Aracı   Galeriden  2. El  274654  162750        False

# %%
ccm = data.loc[data["CCM"] == "1601-1800 cc"]
ccm_2006 = ccm.loc[ccm["Model Yıl"] == 2006]
ccm_2006
# Out:
#      İlan Tarihi     Marka Arac Tip Grubu                Arac Tip  Model Yıl  \
# 450   09/04/2020      Audi             A3            1.6 Ambiente     2006.0
# 1445  12/06/2020     Dacia          Logan            1.4 Ambiance     2006.0
# 2348  15/06/2020      Ford         Fusion                 1.6 Lux     2006.0
# 2386  10/06/2020      Ford         Fusion            1.6 TDCi Lux     2006.0
# 2401  09/06/2020      Ford          Focus           1.6 TDCi Ghia     2006.0
# 2464  30/05/2020      Ford          Focus          1.6 TDCi Trend     2006.0
# 2465  30/05/2020      Ford          Focus          1.6 TDCi Trend     2006.0
# 2489  26/05/2020      Ford          Focus     1.6 TDCi Collection     2006.0
# 2945  24/03/2020      Ford          Focus                1.6 Ghia     2006.0
# 3014  12/06/2020     Honda           CR-V     1.6 i-DTEC Elegance     2006.0
# 3331  10/06/2020   Hyundai         Accent              1.6 Admire     2006.0
# 3807  13/04/2020   Hyundai         Accent              1.6 Admire     2006.0
# 4746  17/04/2020  Mercedes       E Serisi  E 200 Komp. Avantgarde     2006.0
# 4809  17/04/2020  Mercedes       E Serisi  E 200 Komp. Avantgarde     2006.0
# 5274  14/06/2020      Opel          Astra            1.6 Twinport     2006.0
# 5844  11/04/2020      Opel          Astra            1.6 Elegance     2006.0
# 5864  06/04/2020      Opel         Meriva        1.6 16V Essentia     2006.0
# 6297  14/04/2020   Peugeot            407         1.6 HDI Comfort     2006.0
# 8711  11/04/2020      Seat           Leon            1.6 Stylance     2006.0
#
#       Yakıt Turu                Vites           CCM     Beygir Gucu  \
# 450   Benzin/LPG       Otomatik Vites  1601-1800 cc      101-125 BG
# 1445  Benzin/LPG            Düz Vites  1601-1800 cc       76-100 BG
# 2348       Dizel            Düz Vites  1601-1800 cc      101-125 BG
# 2386       Dizel            Düz Vites  1601-1800 cc  100 BG ve altı
# 2401       Dizel       Otomatik Vites  1601-1800 cc      101-125 BG
# 2464       Dizel            Düz Vites  1601-1800 cc      101-125 BG
# 2465       Dizel            Düz Vites  1601-1800 cc      101-125 BG
# 2489       Dizel            Düz Vites  1601-1800 cc      101-125 BG
# 2945       Dizel            Düz Vites  1601-1800 cc        BosDeger
# 3014       Dizel       Otomatik Vites  1601-1800 cc      151-175 BG
# 3331  Benzin/LPG            Düz Vites  1601-1800 cc       76-100 BG
# 3807  Benzin/LPG            Düz Vites  1601-1800 cc  100 BG ve altı
# 4746  Benzin/LPG       Otomatik Vites  1601-1800 cc        BosDeger
# 4809      Benzin  Yarı Otomatik Vites  1601-1800 cc        BosDeger
# 5274  Benzin/LPG            Düz Vites  1601-1800 cc      101-125 BG
# 5844  Benzin/LPG       Otomatik Vites  1601-1800 cc      101-125 BG
# 5864  Benzin/LPG  Yarı Otomatik Vites  1601-1800 cc      101-125 BG
# 6297       Dizel            Düz Vites  1601-1800 cc       76-100 BG
# 8711  Benzin/LPG            Düz Vites  1601-1800 cc      101-125 BG
#
#             Renk         Kasa Tipi      Kimden  Durum      Km   Fiyat  \
# 450        Füme   Hatchback 5 Kapı  Sahibinden  2. El  115000  107000
# 1445      Beyaz              Sedan   Galeriden  2. El  255000   29750
# 2348        Gri   Hatchback 5 Kapı   Galeriden  2. El  218000   52000
# 2386      Gümüş   Hatchback 5 Kapı  Sahibinden  2. El     167   55000
# 2401        Gri   Hatchback 5 Kapı   Galeriden  2. El  196000   63000
# 2464      Beyaz              Sedan  Sahibinden  2. El  230000   60000
# 2465        Gri              Sedan  Sahibinden  2. El  305000   49500
# 2489      Siyah   Hatchback 5 Kapı   Galeriden  2. El  206000   61500
# 2945        Gri              Sedan  Sahibinden  2. El     255   47500
# 3014      Beyaz        Arazi Aracı   Galeriden  2. El   98000  249700
# 3331        Gri              Sedan   Galeriden  2. El     191   38500
# 3807  Gümüş Gri              Sedan  Sahibinden  2. El  736000   24500
# 4746  Gümüş Gri              Sedan   Galeriden  2. El  427000  155000
# 4809      Siyah              Sedan   Galeriden  2. El  386000  136500
# 5274  Gümüş Gri   Hatchback 5 Kapı  Sahibinden  2. El  165000   55000
# 5844      Siyah   Hatchback 5 Kapı  Sahibinden  2. El  223500   62000
# 5864  Gümüş Gri   Hatchback 5 Kapı   Galeriden  2. El  155000   53500
# 6297        Gri              Sedan  Sahibinden  2. El  170000   51000
# 8711      Siyah   Hatchback 5 Kapı   Galeriden  2. El  253000   56750
#
#       Asırı_Deger
# 450         False
# 1445        False
# 2348        False
# 2386        False
# 2401        False
# 2464        False
# 2465        False
# 2489        False
# 2945        False
# 3014        False
# 3331        False
# 3807        False
# 4746        False
# 4809        False
# 5274        False
# 5844        False
# 5864        False
# 6297        False
# 8711        False

# %%
data = data.loc[data.index != 3014]

fig, ax = plt.subplots(figsize=(20, 6))
sns.barplot(x = data.loc[data["Marka"] == "Honda"]["Model Yıl"], y = data["Fiyat"])
# Out:
# <Axes: xlabel='Model Yıl', ylabel='Fiyat'>

# %%
sns.barplot(x = data["Yakıt Turu"], y = data["Fiyat"], data = data)
# Out:
# <Axes: xlabel='Yakıt Turu', ylabel='Fiyat'>

# %%
fig, ax = plt.subplots(figsize = (20, 6))
sns.barplot(x = data["Kasa Tipi"], y = data["Fiyat"], data = data)
# Out:
# <Axes: xlabel='Kasa Tipi', ylabel='Fiyat'>

# %%
sns.barplot(x = data["Vites"], y = data["Fiyat"], data = data)
# Out:
# <Axes: xlabel='Vites', ylabel='Fiyat'>

# %%
sns.barplot(x = data["Durum"], y = data["Fiyat"], data = data)
# Out:
# <Axes: xlabel='Durum', ylabel='Fiyat'>

# %%
sns.barplot(x = data["Kimden"], y = data["Fiyat"], data = data)
# Out:
# <Axes: xlabel='Kimden', ylabel='Fiyat'>

# %%
fig, ax = plt.subplots(figsize = (25, 6))
sns.barplot(x = data["Renk"], y = data["Fiyat"])
# Out:
# <Axes: xlabel='Renk', ylabel='Fiyat'>

# %%
turuncu = data.loc[data["Renk"] == "Turuncu "]
turuncu["Kasa Tipi"].value_counts()
# Out:
# Kasa Tipi
# Arazi Aracı         14
# Hatchback 5 Kapı     9
# Spor / Coupe         1
# Diğer                1
# MPV                  1
# Crossover            1
# Name: count, dtype: int64

# %%
df = pd.read_csv(r"C:\Users\huawe\Documents\Yazilim\Veri\turkey_car_market.csv")

fig, ax = plt.subplots(figsize = (25, 6))
sns.barplot(x = df["Renk"], y = df["Fiyat"])
# Out:
# <Axes: xlabel='Renk', ylabel='Fiyat'>

# %%
data.head()
# Out:
#   İlan Tarihi  Marka Arac Tip Grubu Arac Tip  Model Yıl  Yakıt Turu  \
# 1  16/06/2020  Acura             CL        -     2015.0       Dizel
# 2  14/06/2020  Acura             CL      2.2     1994.0  Benzin/LPG
# 3  11/06/2020  Acura             CL        -     2013.0       Dizel
# 4  11/06/2020  Acura             CL      2.2     2010.0       Dizel
# 5  04/06/2020  Acura             CL      2.2     1999.0       Dizel
#
#                  Vites           CCM Beygir Gucu         Renk Kasa Tipi  \
# 1  Yarı Otomatik Vites  1301-1600 cc  101-125 BG        Mavi      Sedan
# 2            Düz Vites  1301-1600 cc  101-125 BG     Turkuaz      Sedan
# 3            Düz Vites  1301-1600 cc   76-100 BG  Kahverengi      Sedan
# 4       Otomatik Vites  1801-2000 cc  151-175 BG       Beyaz      Sedan
# 5            Düz Vites  1801-2000 cc  101-125 BG    Lacivert   Roadster
#
#        Kimden  Durum      Km   Fiyat  Asırı_Deger
# 1  Sahibinden  2. El  127000  151500        False
# 2  Sahibinden  2. El  175000   19750        False
# 3  Sahibinden  2. El     325   52000        False
# 4  Sahibinden  2. El  207000  148750        False
# 5   Galeriden  2. El  320000   42500        False

# %%
del data["Asırı_Deger"]

from sklearn.preprocessing import LabelEncoder

le = LabelEncoder()

cols = ['Marka', 'Arac Tip Grubu', 'Arac Tip','Yakıt Turu', 'Vites', 'CCM', 'Beygir Gucu', 'Renk', 'Kasa Tipi',
       'Kimden', 'Durum']

for i in cols:
    data[i] = le.fit_transform(data[i])
    
y = data["Fiyat"]
x = data.iloc[:, 1:14]

from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.33, random_state = 45)

x_train.head()
# Out:
#       Marka  Arac Tip Grubu  Arac Tip  Model Yıl  Yakıt Turu  Vites  CCM  \
# 3346     13              83       274     2011.0           1      0    3
# 5639     27              93       137     2013.0           2      0    1
# 6492     30             318       482     2011.0           2      0   14
# 8362     30             177       492     2011.0           2      0    2
# 5201     26             273       778     2012.0           0      2    2
#
#       Beygir Gucu  Renk  Kasa Tipi  Kimden  Durum      Km
# 3346            1     4          9       0      1  225000
# 5639           18    11          9       0      1  212000
# 6492           15     4          9       0      1  241000
# 8362           18     8          9       0      1  345000
# 5201           18    22          0       0      1   49590

# %%
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score


rf = RandomForestRegressor()
rf.fit(x_train, y_train)
rf_tahmin = rf.predict(x_test)

r2_skor = r2_score(y_test, rf_tahmin)
hata_skor = np.sqrt(mean_squared_error(y_test, rf_tahmin))

print("R2_skoru: ", r2_skor)
print("Hata Kare: ", hata_skor)
# Out:
# R2_skoru:  0.9186434190183806
# Hata Kare:  17369.053146056587

# %%
sonuc = pd.DataFrame({'Gerçek Değerler': np.array(y_test).flatten(), 'Tahminler': rf_tahmin.flatten()})
sonuc.head(10)
# Out:
#    Gerçek Değerler      Tahminler
# 0            63750   63750.000000
# 1            62750   69357.940000
# 2            96800   99278.500000
# 3           275000  272888.666667
# 4            94500  109153.990000
# 5            28500   26513.000000
# 6            76500   73765.000000
# 7            46000   44601.500000
# 8           104250  128369.000000
# 9            88000   88000.000000
